# %%
import requests
import json

# Define your Client ID and Client Secret
client_id = "54de70f003a74802a2b6acfbaf8710aa"
client_secret = "2be5535f5e7e44e195dfe88f934741cf"

# Get an access token

def get_access_token():
    token_url = "https://oauth.fatsecret.com/connect/token"
    data = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret,
        "scope": "basic"
    }

    response = requests.post(token_url, data=data)
    access_token = response.json()["access_token"]
    return access_token

# Search for food

def search_food(search_expression):
    access_token = get_access_token()

    api_url = "https://platform.fatsecret.com/rest/server.api"
    params = {
        "method": "foods.search",
        "search_expression": search_expression,
        "format": "json",
        "max_results": 50
    }
    headers = {
        "Authorization": f"Bearer {access_token}"
    }

    response = requests.post(api_url, params=params, headers=headers)
    search_results = response.json()
    return search_results


# Read the dataset file
filename = "C:/Users/Ananda/OneDrive/repos/NutriPal-ML/datasets/indonesian_food.csv"
foods = []

with open(filename, "r") as file:
    next(file)  # Skip the header line
    for line in file:
        food_id, name, tipe = line.strip().split(",")
        foods.append(name)

search_results = {}

for food in foods:
    results = search_food(food)
    if 'foods' in results and 'food' in results['foods']:
        exact_name = []
        food_list = results['foods']['food']
        if isinstance(food_list, dict):
            # Only one result, convert it to a list
            food_list = [food_list]
        for result in food_list:
            if result['food_name'].lower() == food.lower():
                exact_name.append(result)
        search_results[food] = exact_name

# Save the search results to a JSON file
filename = "search_results.json"

with open(filename, "w") as file:
    json.dump(search_results, file)

print(f"Search results saved to {filename}.")
# Out:
# Search results saved to search_results.json.

# %%
import requests
import json

# Define your Client ID and Client Secret
client_id = "54de70f003a74802a2b6acfbaf8710aa"
client_secret = "2be5535f5e7e44e195dfe88f934741cf"

# Get an access token
def get_access_token():
    token_url = "https://oauth.fatsecret.com/connect/token"
    data = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret,
        "scope": "basic"
    }

    response = requests.post(token_url, data=data)
    access_token = response.json()["access_token"]
    return access_token

# Search for food
def search_food(search_expression):
    access_token = get_access_token()

    api_url = "https://platform.fatsecret.com/rest/server.api"
    params = {
        "method": "food.get.v3",
        "food_id": search_expression,
        "format": "json"
    }
    headers = {
        "Authorization": f"Bearer {access_token}"
    }

    response = requests.post(api_url, params=params, headers=headers)
    search_results = response.json()
    return search_results

filename = "C:/Users/Ananda/OneDrive/repos/NutriPal-ML/results/get_results.json"

with open(filename, "w") as file:
    search_expression = ["46827300", "58704864", "68848666", "3721196"]

    for index in range(len(search_expression)):
        results = search_food(search_expression[index])
        print(results)
        json.dump(results, file)

print(f"Search results saved to {filename}.")
# Out:
# {'food': {'brand_name': 'Shirakiku', 'food_id': '46827300', 'food_name': 'Pork Gyoza', 'food_type': 'Brand', 'food_url': 'https://www.fatsecret.com/calories-nutrition/shirakiku/pork-gyoza', 'servings': {'serving': [{'calcium': '40', 'calories': '240', 'carbohydrate': '34.00', 'cholesterol': '15', 'fat': '8.00', 'fiber': '2.0', 'iron': '2.70', 'measurement_description': 'serving', 'metric_serving_amount': '144.000', 'metric_serving_unit': 'g', 'number_of_units': '1.000', 'protein': '9.00', 'saturated_fat': '2.500', 'serving_description': '7 pieces', 'serving_id': '40092479', 'serving_url': 'https://www.fatsecret.com/calories-nutrition/shirakiku/pork-gyoza', 'sodium': '510', 'sugar': '3.00'}]}}}
# ...

# %%
import requests
import json

# Define your Client ID and Client Secret
client_id = "54de70f003a74802a2b6acfbaf8710aa"
client_secret = "ec1481f11fea4da98f1e05a2ad9fae4f"

# Get an access token


def get_access_token():
    token_url = "https://oauth.fatsecret.com/connect/token"
    data = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret,
        "scope": "basic"
    }

    response = requests.post(token_url, data=data)
    access_token = response.json()["access_token"]
    return access_token

# Search for food


def search_food(search_expression):
    access_token = get_access_token()

    api_url = "https://platform.fatsecret.com/rest/server.api"
    params = {
        "method": "food.get.v3",
        "food_id": search_expression,
        "format": "json"
    }
    headers = {
        "Authorization": f"Bearer {access_token}"
    }

    response = requests.post(api_url, params=params, headers=headers)
    search_results = response.json()
    return search_results


# Read the food_ids from id.json
filename = "C:/Users/Ananda/OneDrive/repos/NutriPal-ML/codes/food_ids.json"

with open(filename, "r") as file:
    data = json.load(file)
    food_ids = data["food_ids"]

# Perform food search for each food_id and save the results
filename = "get_results.json"

with open(filename, "w") as file:
    for food_id in food_ids:
        results = search_food(food_id)
        json.dump(results, file)
        file.write("\n")  # Add newline after each JSON object

print(f"Search results saved to {filename}.")
